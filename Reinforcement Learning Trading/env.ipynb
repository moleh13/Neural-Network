# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
price_data = pd.read_csv('BTC-USD.csv')

# %%
class TradingEnvironment:
    def __init__(self, data_path, initial_cash):
        self.data = pd.read_csv(data_path)
        self.initial_cash = initial_cash
        self.cash = initial_cash
        self.position = None
        self.pnl = 0
        self.asset = 0
        self.day = 0
        self.position_day = 0

    def long_position(self):
        if self.position:
            print("You already have a position.")
            return
        else:
            self.position = 'long'
            self.asset = self.cash / self.data['Close'].iloc[self.day]
            self.position_day = self.day

    def close_position(self):
        if not self.position:
            print("You don't have any position to close.")
            return
        else:
            if self.position == 'long':
                self.pnl = self.asset * self.data['Close'].iloc[self.day] - self.data['Close'].iloc[self.position_day] * self.asset
            self.cash += self.pnl
            self.position = None
            self.asset = 0
            print("Position closed. PnL:", self.pnl)
            print("Updated cash balance:", self.cash)

    def step(self, action):
        current_price = self.data['Close'].iloc[self.day]
        unrealized_pnl = self.asset * current_price - self.asset * self.data['Close'].iloc[self.position_day]


        print("Current day:", self.day)
        print("Current price of the asset:", current_price)
        print("Current Asset:", self.asset)
        print("Unrealized PnL:", unrealized_pnl)
        
        if action == 'long':
            self.long_position()
        elif action == 'close':
            self.close_position()
        elif action == 'wait':
            print("Current price of the asset:", current_price)
            pass
        else:
            print("Invalid action.")
        
        print("Current Asset:", self.asset)
        print("Current position:", self.position)
        print("Current cash balance:", self.cash)
        print("***********************************************")
        self.day += 1

# %%
# Example usage:
env = TradingEnvironment('BTC-USD.csv', 1000)
while True:
    env.step()
# Out:
# Current day: 0
# Current price of the asset: 457.3340148925781
# Current Asset: 0
# Unrealized PnL: 0.0
# Current price of the asset: 457.3340148925781
# Current Asset: 0
# Current position: None
# Current cash balance: 1000
# ***********************************************
# Current day: 1
# Current price of the asset: 424.44000244140625
# Current Asset: 0
# Unrealized PnL: 0.0
# Current Asset: 2.356045599490942
# Current position: long
# Current cash balance: 1000
# ***********************************************
# Current day: 2
# Current price of the asset: 394.7959899902344
# Current Asset: 2.356045599490942
# Unrealized PnL: -69.84264508683827
# Position closed. PnL: -69.84264508683827
# Updated cash balance: 930.1573549131617
# Current Asset: 0
# Current position: None
# Current cash balance: 930.1573549131617
# ***********************************************
# Current day: 3
# Current price of the asset: 408.9039916992187
# Current Asset: 0
# Unrealized PnL: 0.0
# Current price of the asset: 408.9039916992187
# Current Asset: 0
# Current position: None
# Current cash balance: 930.1573549131617
# ***********************************************
# Current day: 4
# Current price of the asset: 398.8210144042969
# Current Asset: 0
# Unrealized PnL: 0.0
# You don't have any position to close.
# Current Asset: 0
# Current position: None
# Current cash balance: 930.1573549131617
# ***********************************************
# Current day: 5
# Current price of the asset: 402.1520080566406
# Current Asset: 0
# Unrealized PnL: 0.0
# You don't have any position to close.
# Current Asset: 0
# Current position: None
# Current cash balance: 930.1573549131617
# ***********************************************
# Current day: 6
# Current price of the asset: 435.7909851074219
# Current Asset: 0
# Unrealized PnL: 0.0
# Current price of the asset: 435.7909851074219
# Current Asset: 0
# Current position: None
# Current cash balance: 930.1573549131617
# ***********************************************
# Current day: 7
# Current price of the asset: 423.2049865722656
# Current Asset: 0
# Unrealized PnL: 0.0
# Current price of the asset: 423.2049865722656
# Current Asset: 0
# Current position: None
# Current cash balance: 930.1573549131617
# ***********************************************
# Current day: 8
# Current price of the asset: 411.5740051269531
# Current Asset: 0
# Unrealized PnL: 0.0
# You don't have any position to close.
# Current Asset: 0
# Current position: None
# Current cash balance: 930.1573549131617
# ***********************************************
# Current day: 9
# Current price of the asset: 404.4249877929687
# Current Asset: 0
# Unrealized PnL: 0.0
# Current price of the asset: 404.4249877929687
# Current Asset: 0
# Current position: None
# Current cash balance: 930.1573549131617
# ***********************************************
# Current day: 10
# Current price of the asset: 399.5199890136719
# Current Asset: 0
# Unrealized PnL: 0.0
# Invalid action.
# Current Asset: 0
# Current position: None
# Current cash balance: 930.1573549131617
# ***********************************************
# Current day: 11
# Current price of the asset: 377.1809997558594
# Current Asset: 0
# Unrealized PnL: 0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 4
#       2 env = TradingEnvironment('BTC-USD.csv', 1000)
#       3 while True:
# ----> 4     env.step()
#
# Cell In[14], line 44, in TradingEnvironment.step(self)
#      41 print("Current Asset:", self.asset)
#      42 print("Unrealized PnL:", unrealized_pnl)
# ---> 44 action = input("Choose your action (long/wait/close): ")
#      45 if action == 'long':
#      46     self.long_position()
#
# File ~/Library/Python/3.11/lib/python/site-packages/ipykernel/kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~/Library/Python/3.11/lib/python/site-packages/ipykernel/kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
